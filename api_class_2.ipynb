# %%
import requests

# %%
## LORD OF THE RINGS Api


response=requests.get('https://the-one-api.dev/v2/book')
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'docs': [{'_id': '5cf5805fb53e011a64671582',
#    'name': 'The Fellowship Of The Ring'},
#   {'_id': '5cf58077b53e011a64671583', 'name': 'The Two Towers'},
#   {'_id': '5cf58080b53e011a64671584', 'name': 'The Return Of The King'}],
#  'total': 3,
#  'limit': 1000,
#  'offset': 0,
#  'page': 1,
#  'pages': 1}

# %%
headers={
    "Authorization": "Bearer Rm8uJ4Re8Ju70Uvt3CGC"
}

response=requests.get('https://the-one-api.dev/v2/movie', headers=headers)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'docs': [{'_id': '5cd95395de30eff6ebccde56',
#    'name': 'The Lord of the Rings Series',
#    'runtimeInMinutes': 558,
#    'budgetInMillions': 281,
#    'boxOfficeRevenueInMillions': 2917,
#    'academyAwardNominations': 30,
#    'academyAwardWins': 17,
#    'rottenTomatoesScore': 94},
#   {'_id': '5cd95395de30eff6ebccde57',
#    'name': 'The Hobbit Series',
#    'runtimeInMinutes': 462,
#    'budgetInMillions': 675,
#    'boxOfficeRevenueInMillions': 2932,
#    'academyAwardNominations': 7,
#    'academyAwardWins': 1,
#    'rottenTomatoesScore': 66.33333333},
#   {'_id': '5cd95395de30eff6ebccde58',
#    'name': 'The Unexpected Journey',
#    'runtimeInMinutes': 169,
#    'budgetInMillions': 200,
#    'boxOfficeRevenueInMillions': 1021,
#    'academyAwardNominations': 3,
#    'academyAwardWins': 1,
#    'rottenTomatoesScore': 64},
#   {'_id': '5cd95395de30eff6ebccde59',
#    'name': 'The Desolation of Smaug',
#    'runtimeInMinutes': 161,
#    'budgetInMillions': 217,
# ...

# %%
# !pip install python-dotenv

# %%
from dotenv import load_dotenv

# %%
## ICON Finder

url = "https://api.iconfinder.com/v4/icons/search?query=Love&count=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer zqiFJTrDNz5UPnmEdN49Dc3wlGQHUEjbLWnTwg7VkS6HwAbUkTBVFmBQ3YJksmUn"
}

response = requests.get(url, headers=headers)

response.json()
# Out:
# {'total_count': 175870,
#  'icons': [{'icon_id': 211754,
#    'tags': ['heart'],
#    'published_at': '2013-11-05T21:49:46.825431Z',
#    'is_premium': False,
#    'type': 'vector',
#    'containers': [{'format': 'ico',
#      'download_url': 'https://api.iconfinder.com/v4/icons/211754/containers/ico/download'},
#     {'format': 'icns',
#      'download_url': 'https://api.iconfinder.com/v4/icons/211754/containers/icns/download'}],
#    'raster_sizes': [{'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-ios7-heart-outline-16.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211754/formats/png/16/download'}],
#      'size': 16,
#      'size_width': 16,
#      'size_height': 16},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-ios7-heart-outline-20.png',
# ...

# %%
url="https://54285744-illusion-diffusion.gateway.alpha.fal.ai/"

headers={
    "Authorization": "key 5c5157d7-9f29-474a-bec3-848348cd1454:9cc2e8f445cf45c01a9b2f6e0fcc4768",
    "Content-Type":"application/json"
}
payload ={
    "image_url":"https://storage.googleapis.com/falserverless/illusion-examples/cubes.jpeg",
    "prompt":"(masterpiece:1.4), (best quality), (detailed), Medieval village scene with busy streets and castle in the distance",
    "negative_prompt":"(worst quality, poor details:1.4), lowres, (artist name, signature, watermark:1.4), bad-artist-anime, bad_prompt_version2, bad-hands-5, ng_deepnegative_v1_75t"
}

response = requests.post(url, headers=headers, json=payload)
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '{"image":{"url":"https://storage.googleapis.com/isolate-dev-hot-rooster_toolkit_bucket/github_54285744/e19e0959a9a0427f82bcf924e281b78e.png?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gke-service-account%40isolate-dev-hot-rooster.iam.gserviceaccount.com%2F20240316%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240316T053454Z&X-Goog-Expires=604800&X-Goog-SignedHeaders=host&X-Goog-Signature=...","content_type":"image/png","file_name":"e19e0959a9a0427f82bcf924e281b78e.png","file_size":1938693,"width":1024,"height":1024},"seed":8059383517470023}'

# %%
import json
from PIL import Image
from io import BytesIO
from IPython.display import display

response_text=response.text
response_data = json.loads(response_text)
image_url = response_data['image']['url']

response = requests.get(image_url)


if response.status_code == 200:

    image_data = response.content
    img = Image.open(BytesIO(image_data))

    display(img)
else:
    print("Failed to download image. Status code:", response.status_code)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024>

# %%
url = "https://api.d-id.com/clips"
payload = {
    "script": {
        "type": "text",
        "provider": {
            "type": "microsoft",
            "voice_id": "en-US-JennyNeural"
        },
        "ssml": "false",
        "input": "Hello there. I am your Smart Assistant. How can I help you?"
    },
    "config": { "result_format": "mp4" },
    "presenter_config": { "crop": { "type": "wide" } },
    "background": { "color": "false" },
    "presenter_id": "anita-6_uTzyZtNR"
}
headers = {
    "accept": "application/json",
    "content-type": "application/json",
    "authorization": "Basic Z2FuamJha2hzaC5hbGlAZ21haWwuY29t:Ku8Aw9zYTxmJLnMfFE5hj"
}
response = requests.post(url, json=payload, headers=headers)
print(response.status_code)
response.json()
# Out:
# 201
# {'id': 'clp_L6HUTwh43YLztS3OC-k71',
#  'created_at': '2024-03-16T07:09:08.059Z',
#  'object': 'clip',
#  'status': 'created'}

# %%
url = "https://api.d-id.com/clips/clp_L6HUTwh43YLztS3OC-k71"

headers = {
    "accept": "application/json",
    "authorization": "Basic Z2FuamJha2hzaC5hbGlAZ21haWwuY29t:Ku8Aw9zYTxmJLnMfFE5hj"
}

response = requests.get(url, headers=headers)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'script': {'length': 59,
#   'ssml': False,
#   'subtitles': False,
#   'type': 'text',
#   'provider': {'type': 'microsoft', 'voice_id': 'en-US-JennyNeural'}},
#  'metadata': {'num_frames': 137,
#   'processing_fps': 29.609982497690638,
#   'resolution': [1080, 1080],
#   'size_kib': 7484.72265625},
#  'audio_url': 'https://d-id-clips-prod.s3.us-west-2.amazonaws.com/google-oauth2%7C117018186918757481640/clp_L6HUTwh43YLztS3OC-k71/microsoft.wav?AWSAccessKeyId=AKIA5CUMPJBIJ7CPKJNP&Expires=1710659348&Signature=7Cgq%2FVN72p042NzHC5yFp%2Bd6mwA%3D',
#  'created_at': '2024-03-16T07:09:08.059Z',
#  'config': {'logo': {'url': 'https://d-id-user-logos-prod.s3.us-west-2.amazonaws.com/default/worker/did-watermark-2023.png',
#    'position': [0, 0]},
#   'result_format': '.mp4',
#   'fluent': False,
#   'motion_factor_kp': [1, 0.75]},
#  'source_url': 'https://clips-presenters.d-id.com/anita/6_uTzyZtNR/Ecg7Fd7cJz/thumbnail.png',
#  'created_by': 'google-oauth2|117018186918757481640',
# ...
